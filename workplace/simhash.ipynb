# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from simhash import Simhash, SimhashIndex
from os import listdir
from sklearn.metrics import ndcg_score, dcg_score
import numpy as np
import pandas as pd
from preprocessing import *


def readText(path):
    Text = []
    return Text


def gainVectorizer(textData):
    vectorizer = TfidfVectorizer()
    vectorizer.fit(textData)
    return vectorizer


def gainVocabulary(vectorizer):
    vocabulary = dict((i, w) for w, i in vectorizer.vocabulary_.items())
    return vocabulary


def gainDocsVectors(docs, vectorizer):
    docsVectors = vectorizer.transform(docs)
    return docsVectors


def gainDocsSimhashValues(docsVectors, vocabulary):
    simhashValues = []
    for i in range(docsVectors.shape[0]):
        docVector = docsVectors.getrow(i)
        # features as list of (token, weight) tuples)
        features = zip([vocabulary[j] for j in docVector.indices], docVector.data)
        simhashValues.append(Simhash(features))
        
    return simhashValues


def docsToSimhashValues(docs, vectorizer, vocabulary):
    docsVectors = gainDocsVectors(docs, vectorizer)
    docsSimhashValues = gainDocsSimhashValues(docsVectors, vocabulary)
    return docsSimhashValues


    
def gainFormattedQuery(query: str)-> list:
    return [query]
    
    
def queryToSimHashValue(query, vectorizer, vocabulary):
    formattedQuery = gainFormattedQuery(query)
    querySimhashValue = docsToSimhashValues(formattedQuery, vectorizer, vocabulary)
    return querySimhashValue[0]
    
    
def gainSimhashValueDistance(simhashValue1, simhashValue2):
    return simhashValue1.distance(simhashValue2)


def gainDistancOfTwoDocs(doc1, doc2, vectorizer, vocabulary):
    doc1SimhashValue = queryToSimHashValue(doc1, vectorizer, vocabulary)
    doc2SimhashValue = queryToSimHashValue(doc2, vectorizer, vocabulary)
    
    return gainSimhashValueDistance(doc1SimhashValue, doc2SimhashValue)


def argsort(seq):
    return sorted(range(len(seq)), key=seq.__getitem__)


def gainTopNAnswers(query, optionalDocs, vectorizer, vocabulary, n):
    if n >= len(optionalDocs):
        n = len(optionalDocs)

    querySimhashValue = queryToSimHashValue(query, vectorizer, vocabulary)
    optionalDocsSimhashValues = docsToSimhashValues(optionalDocs, vectorizer, vocabulary)
    distances = []
    for optionalDocsSimhashValue in optionalDocsSimhashValues:
        distances.append(gainSimhashValueDistance(querySimhashValue, optionalDocsSimhashValue))
    
    sortedIndices = argsort(distances)
    returnedAnswers = []
    for i in range(n):
        returnedAnswers.append(optionalDocs[sortedIndices[i]])
        
    return returnedAnswers

def gainTopNAnswersIndices(query, optionalDocs, vectorizer, vocabulary, n):
    if n >= len(optionalDocs):
        n = len(optionalDocs)

    querySimhashValue = queryToSimHashValue(query, vectorizer, vocabulary)
    optionalDocsSimhashValues = docsToSimhashValues(optionalDocs, vectorizer, vocabulary)
    distances = []
    for optionalDocsSimhashValue in optionalDocsSimhashValues:
        distances.append(gainSimhashValueDistance(querySimhashValue, optionalDocsSimhashValue))
    
    sortedIndices = argsort(distances)
        
    return sortedIndices

# %%
# For sampling use: get the sampling documents
annotate_result = pd.read_csv('../data/annotate_result.csv', encoding='utf-8', header=0)
remain_city_country_list = annotate_result['city'].tolist()


doc_filenames = sorted(listdir('../data/sample_docs'))
sample_docs = []
city_country_names = []
for i in range(len(doc_filenames)):
    line = doc_filenames[i].split('_')
    if "('" + line[0] + "', '" + line[1] + "')" in remain_city_country_list:
        city_country_names.append((line[0], line[1]))
        with open('../data/sample_docs/' + doc_filenames[i], 'r', encoding='utf-8') as df:
            doc = df.read()
            sample_docs.append(doc)

tokenized_corpus = []
corpus = []
for ind1, doc in enumerate(sample_docs):
    doc = str(doc)
    name = city_country_names[ind1][0].lower()
    corpus.append(doc)
#     # print(name)
    tokens = preprocess(doc, name)
    tokenized_corpus.append(tokens)

# # Convert to appropriate format for later use
corpus = [" ".join(docTokens) for docTokens in tokenized_corpus]
optionalDocs = corpus
vectorizer = gainVectorizer(optionalDocs)
vocabulary = gainVocabulary(vectorizer)
n = 100
top_10_test_queries = [["waterfall"], ["silk"], ["desert"],["volcano"],["beer"],["coconut"],["seafood"]]
top_100_test_queries = [["football"], ["castle"], ["shopping"], ['monument'], ["forest"]]

for q in top_100_test_queries:
    print("------------------{}------------------".format(q[0]))
    
    answersIndices = gainTopNAnswersIndices(q[0], optionalDocs, vectorizer, vocabulary, n)
    top_n = [city_country_names[answersIndices[i]] for i in range(n)]
    print([(pair[0].encode('utf-8'), pair[1].encode('utf-8'))for pair in top_n])

    # NDCG evaluations:
    relevance_score = [1 for i in range(n)]

    annotate_result = pd.read_csv('../data/annotate_result.csv', encoding='utf-8', header=0)

    true_relevence = []
    for top_city in top_n:
        true_relevence.append(annotate_result[annotate_result['city'] == str((top_city[0], top_city[1]))].squeeze()[q[0]])

    # Releveance scores in Ideal order 
    true_relevance = np.asarray([true_relevence]) 
    
    # Releveance scores in output order 
    relevance_score = np.asarray([relevance_score]) 

    print(ndcg_score( true_relevance, relevance_score))
# Out:
# ------------------football------------------
# [(b'Chicago Heights', b'United States'), (b'Chongqing', b'China'), (b'Nerang', b'Australia'), (b'Civitavecchia', b'Italy'), (b'Troy', b'United States'), (b'Aarau', b'Switzerland'), (b'Albano Laziale', b'Italy'), (b'Draper', b'United States'), (b'Enschede', b'Netherlands'), (b'Jingmen', b'China'), (b'Khabarovsk', b'Russia'), (b'Painesville', b'United States'), (b'Poprad', b'Slovakia'), (b'Suceava', b'Romania'), (b'Tuttlingen', b'Germany'), (b'Weimar', b'Germany'), (b'Wooster', b'United States'), (b'Abbotsford', b'Canada'), (b'Benin City', b'Nigeria'), (b'Caboolture', b'Australia'), (b'Faribault', b'United States'), (b'Foster City', b'United States'), (b'Kirandul', b'India'), (b'Lake Oswego', b'United States'), (b'Lier', b'Belgium'), (b'Pasadena', b'United States'), (b'Solna', b'Sweden'), (b'Thomasville', b'United States'), (b'Warwick', b'United Kingdom'), (b'Waterloo', b'Canada'), (b'Xanten', b'Germany'), (b'Abuja', b'Nigeria'), (b'Akola', b'India'), (b'Baar', b'Switzerland'), (b'Bor\xc3\xa5s', b'Sweden'), (b'Brugherio', b'Italy'), (b'Edinburgh', b'United Kingdom'), (b'Gurnee', b'United States'), (b'G\xc4\x81ndarbal', b'India'), (b'Humacao', b'Puerto Rico'), (b'Incheon', b'South Korea'), (b'Kamen\xe2\x80\x99-na-Obi', b'Russia'), (b'Kirkland', b'United States'), (b'Milas', b'Turkey'), (b'Monthey', b'Switzerland'), (b'Morgan Hill', b'United States'), (b'Natchez', b'United States'), (b'Oak Harbor', b'United States'), (b'Oakland', b'United States'), (b'Paramaribo', b'Suriname'), (b'Petr\xc3\xb3polis', b'Brazil'), (b'Pithor\xc4\x81garh', b'India'), (b'Portadown', b'United Kingdom'), (b'Sarov', b'Russia'), (b'Shrewsbury', b'United States'), (b'Sterling Heights', b'United States'), (b'Stralsund', b'Germany'), (b'Truro', b'Canada'), (b'Tver', b'Russia'), (b'Twentynine Palms', b'United States'), (b'Z\xc3\xbcrich (Kreis 6)', b'Switzerland'), (b'Ararat', b'Armenia'), (b'Ashtarak', b'Armenia'), (b'Bauang', b'Philippines'), (b'Berwyn', b'United States'), (b'Chuncheon', b'South Korea'), (b'Ciudad de Huajuapan de Le\xc3\xb3n', b'Mexico'), (b'Crystal Lake', b'United States'), (b'Deventer', b'Netherlands'), (b'Douai', b'France'), (b'Gaborone', b'Botswana'), (b'General Trias', b'Philippines'), (b'Gorizia', b'Italy'), (b'Grand Rapids', b'United States'), (b'Hyderabad', b'Pakistan'), (b'Ila Orangun', b'Nigeria'), (b'Isesaki', b'Japan'), (b'Karlsruhe', b'Germany'), (b'Kentwood', b'United States'), (b'Kitchener', b'Canada'), (b'Koblenz', b'Germany'), (b'Kolomna', b'Russia'), (b'Limoges', b'France'), (b'Little Rock', b'United States'), (b'Marina di Carrara', b'Italy'), (b'Mildura', b'Australia'), (b'Moorpark', b'United States'), (b'Munich', b'Germany'), (b'Neenah', b'United States'), (b'Nizhniy Tagil', b'Russia'), (b'Northallerton', b'United Kingdom'), (b'Owerri', b'Nigeria'), (b'Prievidza', b'Slovakia'), (b'Radcliff', b'United States'), (b'Rapperswil', b'Switzerland'), (b'Raytown', b'United States'), (b'Regensburg', b'Germany'), (b'Rizhao', b'China'), (b'Sacramento', b'United States'), (b'Saratov', b'Russia')]
# 0.6153844429057951
# ------------------castle------------------
# [(b'Lima', b'United States'), (b'Essex', b'United States'), (b'Sigmaringen', b'Germany'), (b'Rew\xc4\x81ri', b'India'), (b'Deggendorf', b'Germany'), (b'Santa Rosa', b'United States'), (b'Koidu', b'Sierra Leone'), (b'Solingen', b'Germany'), (b'T\xc3\xa2rgu-Mure\xc5\x9f', b'Romania'), (b'Agartala', b'India'), (b'Bhav\xc4\x81ni', b'India'), (b'Grafton', b'United States'), (b'Jilin', b'China'), (b'Lanciano', b'Italy'), (b'Musoma', b'Tanzania'), (b'New York City', b'United States'), (b'Octeville', b'France'), (b'Orangevale', b'United States'), (b'Pozzuoli', b'Italy'), (b'Rapperswil', b'Switzerland'), (b'Th\xc3\xadvai', b'Greece'), (b'Waterville', b'United States'), (b'Aiken', b'United States'), (b'Alkmaar', b'Netherlands'), (b'Calais', b'France'), (b'Hondarribia', b'Spain'), (b'Husum', b'Germany'), (b'Jeddah', b'Saudi Arabia'), (b'Kirchheim unter Teck', b'Germany'), (b'Navojoa', b'Mexico'), (b'Nihtaur', b'India'), (b'Palmerston North', b'New Zealand'), (b'Pearl City', b'United States'), (b'P\xc3\xa1pa', b'Hungary'), (b'Ra', b'anana'), (b'Remedios', b'Cuba'), (b'Ukhta', b'Russia'), (b'Vlissingen', b'Netherlands'), (b'Xenia', b'United States'), (b'Zaventem', b'Belgium'), (b'Al Miny\xc4\x81', b'Egypt'), (b'Alings\xc3\xa5s', b'Sweden'), (b'Alsfeld', b'Germany'), (b'Ararat', b'Armenia'), (b'Arkhangel\xe2\x80\x99sk', b'Russia'), (b'Athens', b'Greece'), (b'Brest', b'France'), (b'Budhl\xc4\x81da', b'India'), (b'Chetumal', b'Mexico'), (b'Ch\xc4\x81kan', b'India'), (b'Corcoran', b'United States'), (b'Crystal Lake', b'United States'), (b'Delft', b'Netherlands'), (b'Dipolog', b'Philippines'), (b'Do\xc4\x9fubayaz\xc4\xb1t', b'Turkey'), (b'El Cerrito', b'Colombia'), (b'Enugu-Ezike', b'Nigeria'), (b'Fair Lawn', b'United States'), (b'Friedrichsdorf', b'Germany'), (b'Haguenau', b'France'), (b'Isesaki', b'Japan'), (b'Issaquah', b'United States'), (b'Kajaani', b'Finland'), (b'K\xc5\x8dfu', b'Japan'), (b'Limoges', b'France'), (b'Manali', b'India'), (b'Mekn\xc3\xa8s', b'Morocco'), (b'M\xc5\x82awa', b'Poland'), (b'Nabua', b'Philippines'), (b'Neumarkt in der Oberpfalz', b'Germany'), (b'Nowy Targ', b'Poland'), (b'P\xc3\xa9cs', b'Hungary'), (b'Qusar', b'Azerbaijan'), (b'Riberalta', b'Bolivia'), (b'Saint-Laurent', b'Canada'), (b'Salinas', b'Ecuador'), (b'Severomorsk', b'Russia'), (b'Stevenage', b'United Kingdom'), (b'Wangaratta', b'Australia'), (b'Warwick', b'United Kingdom'), (b'West Islip', b'United States'), (b'Zug', b'Switzerland'), (b'Al Mansoura', b'Egypt'), (b'Altamira', b'Brazil'), (b'Andijon', b'Uzbekistan'), (b'Bad Kreuznach', b'Germany'), (b'Bangil', b'Indonesia'), (b'Bh\xc4\x81y\xc4\x81vadar', b'India'), (b'Bristol', b'United Kingdom'), (b'Bury St Edmunds', b'United Kingdom'), (b'Canterbury', b'United Kingdom'), (b'Cartaya', b'Spain'), (b'Cherry Hill', b'United States'), (b'Ennis', b'Ireland'), (b'Four Corners', b'United States'), (b'Geraldton', b'Australia'), (b'Hamtramck', b'United States'), (b'Ieper', b'Belgium'), (b'Incheon', b'South Korea'), (b'Jacksonville Beach', b'United States')]
# 0.6052878374795588
# ------------------shopping------------------
# [(b'Catemaco', b'Mexico'), (b'Kazanl\xc5\xadk', b'Bulgaria'), (b'Chancay', b'Peru'), (b'Tegal', b'Indonesia'), (b'Urbana', b'United States'), (b'Gjakov\xc3\xab', b'Kosovo'), (b'Hondarribia', b'Spain'), (b'Inver Grove Heights', b'United States'), (b'Khuld\xc4\x81b\xc4\x81d', b'India'), (b'L\xc3\xa9vis', b'Canada'), (b'Madrid', b'Spain'), (b'Sk\xc3\xb6vde', b'Sweden'), (b'Tomsk', b'Russia'), (b'Antalya', b'Turkey'), (b'Arakkonam', b'India'), (b'Bauang', b'Philippines'), (b'Bhav\xc4\x81ni', b'India'), (b'Bideford', b'United Kingdom'), (b'Camberley', b'United Kingdom'), (b'Charlotte Amalie', b'U.S. Virgin Islands'), (b'Ch\xc4\x81kan', b'India'), (b'Florencia', b'Cuba'), (b'Jamkhandi', b'India'), (b'Kajaani', b'Finland'), (b'Puerto de la Cruz', b'Spain'), (b'Qom', b'Iran'), (b'Santar\xc3\xa9m', b'Portugal'), (b'Tawau', b'Malaysia'), (b'Winter Gardens', b'United States'), (b'Agua Dulce', b'Mexico'), (b'Cherry Hill', b'United States'), (b'Clermont-Ferrand', b'France'), (b'Coalville', b'United Kingdom'), (b'Enschede', b'Netherlands'), (b'Makeni', b'Sierra Leone'), (b'Montlu\xc3\xa7on', b'France'), (b'Nieder-Ingelheim', b'Germany'), (b'Oakland', b'United States'), (b'Panauti\xcc\x87\xcc\x84', b'Nepal'), (b'Pernik', b'Bulgaria'), (b'Po\xc3\xa7os de Caldas', b'Brazil'), (b'Sacav\xc3\xa9m', b'Portugal'), (b'San Luis', b'United States'), (b'Spanish Town', b'Jamaica'), (b'Trubchevsk', b'Russia'), (b'Yellowknife', b'Canada'), (b'Zacatecas', b'Mexico'), (b'Al Miny\xc4\x81', b'Egypt'), (b'Atherton', b'United Kingdom'), (b'Badalona', b'Spain'), (b'Buffalo Grove', b'United States'), (b'B\xc3\xadlina Kyselka', b'Czech Republic'), (b'Celle', b'Germany'), (b'Charleston', b'United States'), (b'Chetumal', b'Mexico'), (b'Contai', b'India'), (b'Donaghmede', b'Ireland'), (b'Do\xc4\x9fubayaz\xc4\xb1t', b'Turkey'), (b'El Cerrito', b'Colombia'), (b'Gaborone', b'Botswana'), (b'Glostrup', b'Denmark'), (b'Holden', b'United States'), (b'Izhevsk', b'Russia'), (b'Juiz de Fora', b'Brazil'), (b'Kabul', b'Afghanistan'), (b'K\xc5\x8dfu', b'Japan'), (b'Madanapalle', b'India'), (b'Magnitogorsk', b'Russia'), (b'Mansfield Woodhouse', b'United Kingdom'), (b'Mor\xc3\xb3n', b'Cuba'), (b'M\xc3\xbcnster', b'Germany'), (b'Northallerton', b'United Kingdom'), (b'Nuevo San Carlos', b'Guatemala'), (b'Okolona', b'United States'), (b'Oranjestad', b'Aruba'), (b'Par\xc3\xa1 de Minas', b'Brazil'), (b'Perai', b'Malaysia'), (b'Pskov', b'Russia'), (b'Rajapalaiyam', b'India'), (b'Sathyamangalam', b'India'), (b'Socorro', b'United States'), (b'Soissons', b'France'), (b'S\xc3\xa3o Lu\xc3\xads do Quitunde', b'Brazil'), (b'Tandag', b'Philippines'), (b'Targovishte', b'Bulgaria'), (b'Th\xc3\xadvai', b'Greece'), (b'Tonal\xc3\xa1', b'Mexico'), (b'Villeneuve-d', b'Ascq'), (b'Ware', b'United Kingdom'), (b'Warwick', b'United Kingdom'), (b'Aiken', b'United States'), (b'Alagir', b'Russia'), (b'Alzira', b'Spain'), (b'Ambato', b'Ecuador'), (b'And\xc3\xbajar', b'Spain'), (b'Arcadia', b'United States'), (b'Bielsko-Biala', b'Poland'), (b'Boone', b'United States'), (b'Bor\xc3\xa5s', b'Sweden'), (b'Burton upon Trent', b'United Kingdom')]
# 0.548671493755796
# ------------------monument------------------
# [(b'Saint Albans', b'Australia'), (b'Alpharetta', b'United States'), (b'Kozan', b'Turkey'), (b'Tha Mai', b'Thailand'), (b'Timi\xc5\x9foara', b'Romania'), (b'Zeytinburnu', b'Turkey'), (b'Ry\xc5\xab\xc5\x8d', b'Japan'), (b'Salavat', b'Russia'), (b'Bhav\xc4\x81ni', b'India'), (b'Gampola', b'Sri Lanka'), (b'Izhevsk', b'Russia'), (b'Paragould', b'United States'), (b'Parsippany', b'United States'), (b'San Juan', b'Philippines'), (b'Utsunomiya', b'Japan'), (b'Antelope', b'United States'), (b'Bal\xc4\xb1kesir', b'Turkey'), (b'Ba\xc4\x8dka Palanka', b'Serbia'), (b'Brawley', b'United States'), (b'Clermont-Ferrand', b'France'), (b'Crawfordsville', b'United States'), (b'Hondarribia', b'Spain'), (b'Husum', b'Germany'), (b'Inver Grove Heights', b'United States'), (b'Iquique', b'Chile'), (b'Jacksonville Beach', b'United States'), (b'Madrid', b'Spain'), (b'Manzanillo', b'Mexico'), (b'Milas', b'Turkey'), (b'Okrika', b'Nigeria'), (b'Phultala', b'Bangladesh'), (b'Rakovski', b'Bulgaria'), (b'Saint-L\xc3\xb4', b'France'), (b'Sankt Wendel', b'Germany'), (b'Santa Cruz Xoxocotl\xc3\xa1n', b'Mexico'), (b'Saugus', b'United States'), (b'Singrauli', b'India'), (b'Terrytown', b'United States'), (b'Airdrie', b'Canada'), (b'Alboraya', b'Spain'), (b'Apaseo el Grande', b'Mexico'), (b'Bandar', b'Indonesia'), (b'B\xc4\x81ri', b'India'), (b'Ch\xc4\x81kan', b'India'), (b'Edirne', b'Turkey'), (b'Fair Lawn', b'United States'), (b'Hoboken', b'United States'), (b'Ipiales', b'Colombia'), (b'Kajaani', b'Finland'), (b'Kor\xc4\x81put', b'India'), (b'K\xc4\x81ranja', b'India'), (b'Limoges', b'France'), (b'Loveland', b'United States'), (b'L\xc3\xbcdenscheid', b'Germany'), (b'Medina', b'United States'), (b'Neckarsulm', b'Germany'), (b'Nha Trang', b'Vietnam'), (b'Northallerton', b'United Kingdom'), (b'Orangevale', b'United States'), (b'Qom', b'Iran'), (b'Salinas', b'Ecuador'), (b'Sathyamangalam', b'India'), (b'Segovia', b'Spain'), (b'Springboro', b'United States'), (b'Tupelo', b'United States'), (b'V\xc3\xb3los', b'Greece'), (b'Aiken', b'United States'), (b'Alagir', b'Russia'), (b'Alzira', b'Spain'), (b'Badajoz', b'Spain'), (b'Badlapur', b'India'), (b'Bareilly', b'India'), (b'Boone', b'United States'), (b'Bor', b'Serbia'), (b'Bourges', b'France'), (b'Cartaya', b'Spain'), (b'Cisterna di Latina', b'Italy'), (b'Dharmapuri', b'India'), (b'Duarte', b'United States'), (b'Eastlake', b'United States'), (b'Enschede', b'Netherlands'), (b'Frankston East', b'Australia'), (b'Gjakov\xc3\xab', b'Kosovo'), (b'Glendale', b'United States'), (b'Hamtramck', b'United States'), (b'H\xc4\x81bra', b'India'), (b'Isleworth', b'United Kingdom'), (b'Jharia', b'India'), (b'Kamakura', b'Japan'), (b'Marseille 05', b'France'), (b'Miami Gardens', b'United States'), (b'Missoula', b'United States'), (b'Montauban', b'France'), (b'M\xc4\x81velikara', b'India'), (b'Newmarket', b'United Kingdom'), (b'Obertshausen', b'Germany'), (b'Orange Walk', b'Belize'), (b'Pau', b'France'), (b'Pearl City', b'United States'), (b'Pililla', b'Philippines')]
# 0.4776055376763678
# ------------------forest------------------
# [(b'Himatnagar', b'India'), (b'Marseille 05', b'France'), (b'Pontevedra', b'Spain'), (b'Qu\xc3\xa9bec', b'Canada'), (b'Ry\xc5\xab\xc5\x8d', b'Japan'), (b'K\xc4\x81ranja', b'India'), (b'Barda', b'Azerbaijan'), (b'Crawfordsville', b'United States'), (b'Hoppers Crossing', b'Australia'), (b'Kairouan', b'Tunisia'), (b'Kangayam', b'India'), (b'Rize', b'Turkey'), (b'Rome', b'Italy'), (b'Aranda de Duero', b'Spain'), (b'Ariccia', b'Italy'), (b'Az\xcc\xa7 Z\xcc\xa7\xc4\x81hir\xc4\xabyah', b'Palestinian Territory'), (b'Badalona', b'Spain'), (b'Chieri', b'Italy'), (b'Contai', b'India'), (b'Florencia', b'Cuba'), (b'Foshan', b'China'), (b'La Crosse', b'United States'), (b'Lier', b'Belgium'), (b'L\xc5\xabn\xc4\x81v\xc4\x81da', b'India'), (b'Melton Mowbray', b'United Kingdom'), (b'Reigate', b'United Kingdom'), (b'Rodez', b'France'), (b'Rovaniemi', b'Finland'), (b'Sacramento', b'United States'), (b'Sathyamangalam', b'India'), (b'Sharjah', b'United Arab Emirates'), (b'Solna', b'Sweden'), (b'Walvis Bay', b'Namibia'), (b'Yaroslavl', b'Russia'), (b'Zhanjiang', b'China'), (b'Alzira', b'Spain'), (b'Ambato', b'Ecuador'), (b'And\xc3\xbajar', b'Spain'), (b'Arlington Heights', b'United States'), (b'Badlapur', b'India'), (b'Beloretsk', b'Russia'), (b'Bor\xc3\xa5s', b'Sweden'), (b'Castel Volturno', b'Italy'), (b'Cherry Hill', b'United States'), (b'Cremona', b'Italy'), (b'Deogarh', b'India'), (b'Dubno', b'Ukraine'), (b'Eastlake', b'United States'), (b'Gjakov\xc3\xab', b'Kosovo'), (b'Grosse Pointe Woods', b'United States'), (b'Hinsdale', b'United States'), (b'Huntington Beach', b'United States'), (b'Hurghada', b'Egypt'), (b'Iquique', b'Chile'), (b'Karur', b'India'), (b'Khuld\xc4\x81b\xc4\x81d', b'India'), (b'Kokkola', b'Finland'), (b'K\xc4\x81nchr\xc4\x81p\xc4\x81ra', b'India'), (b'Leeuwarden', b'Netherlands'), (b'Limbang', b'Malaysia'), (b'L\xc3\xa9vis', b'Canada'), (b'Mackay', b'Australia'), (b'Mawlamyine', b'Myanmar'), (b'Milas', b'Turkey'), (b'Monthey', b'Switzerland'), (b'Natchez', b'United States'), (b'Newbury', b'United Kingdom'), (b'Ogden', b'United States'), (b'Phultala', b'Bangladesh'), (b'Sa P\xc3\xa1', b'Vietnam'), (b'Sacav\xc3\xa9m', b'Portugal'), (b'Tianjin', b'China'), (b'Ulsan', b'South Korea'), (b'Valparai', b'India'), (b'Vlissingen', b'Netherlands'), (b'Zalaegerszeg', b'Hungary'), (b'Alpharetta', b'United States'), (b'Antalya', b'Turkey'), (b'Arcot', b'India'), (b'Arrah', b'India'), (b'Baguio', b'Philippines'), (b'Bellary', b'India'), (b'Berwyn', b'United States'), (b'Brest', b'France'), (b'Carteret', b'United States'), (b'Chuncheon', b'South Korea'), (b'Commerce City', b'United States'), (b'Conakry', b'Guinea'), (b'Deventer', b'Netherlands'), (b'Donaghmede', b'Ireland'), (b'Druskininkai', b'Lithuania'), (b'Formosa', b'Argentina'), (b'Friedrichsdorf', b'Germany'), (b'Ilorin', b'Nigeria'), (b'Kajaani', b'Finland'), (b'Kannauj', b'India'), (b'Kimry', b'Russia'), (b'Kozan', b'Turkey'), (b'K\xc5\x8dfu', b'Japan'), (b'Lachhmangarh S\xc4\xabkar', b'India')]
# 0.548671493755796
